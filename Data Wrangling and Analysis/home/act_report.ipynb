# %% [markdown]
# # Report: act_report By Ashim Sharma

# %% [markdown]
# # <center> Information about WeRateDogs</center>

# %% [markdown]
# ![WhatsApp%20Image%202022-11-08%20at%201.40.54%20PM.jpeg](attachment:WhatsApp%20Image%202022-11-08%20at%201.40.54%20PM.jpeg)

# %% [markdown]
# #### *A well-known Twitter account called WeRateDogs gives ratings to people's dogs and makes amusing comments about the canines.* People are asked to contribute pictures of their pets to WeRateDogs, which then tweets the best ones with a rating and witty commentary. On a scale from one to ten, dogs are assessed, although ratings always exceed the limit, such as 11/10, 12/10, 13/10, etc. It is illogical that these ratings exist. However, why are they even here? because ""Pawan, they're astonishing dogs," He said. After a noteworthy debate in which someone raised dissatisfaction of their rating system, the Twitter user @dog rates made this well-known remark.. WeRateDogs' distinctive rating system, however, plays a significant role in its success.the international media because of its popularity as well as the fact that it brought attention to social media copyright law. The account was created in 2015 by college student Matt Nelson. About 9.3 million people were following the Twitter account as of November 2022.

# %% [markdown]
# ![WhatsApp%20Image%202022-11-08%20at%201.41.00%20PM.jpeg](attachment:WhatsApp%20Image%202022-11-08%20at%201.41.00%20PM.jpeg)
#
#
# This tweet has a 12/10 rating and is about a dog named Gene. It seems very adorable! I've read a lot of thought-provoking tweets, so I started to wonder what the most frequently tweeted dog breeds were. What are those breeds' typical ratings? What dog stage appears to be the most frequently in tweets? I'll concentrate primarily on those questions in the project's analysis section. I've collected data for this study from many sources in a variety of formats, evaluated it, and cleaned it before performing the analysis and creating the graphic.Anyhow i love dogs and want to study more about their behaviours, the positions which convey some messages.

# %% [markdown]
# ## 1. Which dog breeds are the most popular?

# %% [markdown]
# ![top%2010%20popular%20breeds.JPG](attachment:top%2010%20popular%20breeds.JPG)
# ![counts.JPG](attachment:counts.JPG)

# %% [markdown]
# ## Insights from the above Graph:
# To keep tweets about dogs solely, we sanitized the image prediction data. The Golden Retriever is the most popular dog breed, according to the graph, which shows 156 tweets about it. 106 tweets on the Labrador retriever make it the second most popular breed. Pembroke (94), Chihuahua (88), and Pug (62), followed in decreasing order by other breeds, are the following three breeds. Then, using data from favorites and retweets, we'll plot the most popular dog breeds.

# %% [markdown]
# ![favourite.JPG](attachment:favourite.JPG)![retweet.JPG](attachment:retweet.JPG)

# %% [markdown]
# ## Insights From the above Bar graphs:
# Golden retrievers, Labrador retrievers, Pembroke, Chihuahua, Pug, Toy poodle, Chow, and Samoyed are the top 10 most popular breeds according to the number of tweets. In decreasing order, Pomeranian, Malamute, and Chesapeake Bay retriever. Golden retrievers, Labrador retrievers, Pembroke, Chihuahua, Samoyed, French bulldog, Cocker spaniels, Chow, Pug, Toy poodles, and Pomeranians are the top 10 breeds according to the number of retweets. Top 10 breeds based on favorite count are very similar to retweet count (with the exception of the 5th-ranked French bulldog, 6th-ranked Chow, 7th-ranked Cocker spaniel, and 10th-ranked Malamute). This is likely because there may be a correlation between favorites and retweets since people who retweet are more likely to click favorites. The three graphs show the same pattern, showing that the top four dog breeds in popularity are the golden retriever, labrador retriever, pembroke, and chihuahua.<b>Golden retrievers</b> is ranked 1st on the List in terms of Retweet and favourite counts.

# %% [markdown]
# ## 2.Based on the quantity of tweets, what are the popular breeds' average ratings?

# %% [markdown]
# ![average.JPG](attachment:average.JPG)![avg.JPG](attachment:avg.JPG)

# %% [markdown]
# ### From the above data we can depict that there is very few difference between the rating of all the breeds

# %% [markdown]
# ## 3. What phase of a dog is most typical?

# %% [markdown]
# ![pie.JPG](attachment:pie.JPG)

# %% [markdown]
# According to the pie chart, more than 80% of tweets do not include information about the dog phase in the article. Pupper is the most frequent phase among all those tweets for individuals who have the phase information.
